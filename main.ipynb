# %% [markdown]
# ## Load Environment Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src.Agent.builder import get_agent_app

# ສ້າງ app
app = get_agent_app()

# ແລ່ນ workflow
result = app.invoke({
    "question": "ແມ່ນໃຜເປັນຄົນຊື່ສິນຄ້າຫລາຍກວ່າຫມູ່ ແລະ ຊື່ຍັງແນ່ ຂໍເບີ່ງລາຍລະອຽດແນ່",
    "messages": []
})
# Out:
# 2025-12-08 21:42:26.589 | INFO     | src.Agent.builder:_build_workflow:36 - ✅ Workflow graph built successfully
# 2025-12-08 21:42:26.647 | INFO     | src.Agent.nodes:get_schema_node:15 - 📊 Executing Get Schema Node: Fetching all tables from test_visualization...
# 2025-12-08 21:42:26.663 | INFO     | src.DB.db_config:get_db_connection:21 - ✅ Connected to MariaDB successfully
# 2025-12-08 21:42:26.677 | SUCCESS  | src.Agent.nodes:get_schema_node:65 - ✅ Schema fetched successfully: 6 tables
# 2025-12-08 21:42:26.684 | INFO     | src.Agent.nodes:sql_agent_node:119 - 🤖 Generating SQL (JSON Mode)...
# 2025-12-08 21:42:26.686 | INFO     | src.Model_Provider.llm_config:get_router_llm:23 - 🤖 Initializing Groq LLM: moonshotai/kimi-k2-instruct-0905
# ...
